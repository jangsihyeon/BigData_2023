# %% [markdown]
# ### 셀레니움 사용법
#
# - 셀레니움, 크롬 기반(웹브라우저) 자동으로 데이터를 가져올 수 있는 라이브러리
# - RPA(Robot Processing Automation) 업무 자동화
#     - 예 ) 퇴근전 네이버 쇼핑 회사 제품 판매 현황 자동화를 걸어놓고, 다음날 아침에 출근하면 엑셀에 만여개 데이터 수집 완료

# %% [markdown]
# ### 셀레니움 모듈 설치 방법
#
# - 셀레니움 모듈 설치
# - 크롬 드라이버
#
# ```
# python
#
# !pip install selenium
# ```

# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver

# %% [markdown]
# ### Chromedriver 설치
#
# - 이따가 정리
#
#
#     - 사용법
#
# ```
# python
# ```

# %%
# 인코딩 문제로 이렇게 나옴 - cmd 창에서 확인 가능 
# !chromedriver --version
# Out:
# 'chromedriver'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 크롬이 자동화된 테스트 소프트웨어에 의해 제어되고 있습니다. 
driver = webdriver.Chrome()
# 이게 떠 있어야지 가능

# %%
# 셀레니움이 연 크롬의 URL 입력 
url = 'https://www.danawa.com'
driver.get(url)

# %%
# 소스 긁어오기 
html = driver.page_source
html
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko" class=" js no-touch"><head>\n<title>스마트한 쇼핑검색, 다나와! : 가격비교 사이트</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="Title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트"><meta name="Description" content="가격비교 사이트 - 온라인 쇼핑몰, 소셜커머스 전 상품 정보 가격비교 사이트, 비교하면 다나와"><meta name="Keywords" content="가격비교, 상품 추천, 가격비교사이트, 다나와, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 최저가, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑"><meta name="Subject" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트">\n<meta name="author" content="http://www.danawa.com">\n<meta name="robots" content="index, follow">\n<meta property="og:title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트">\n<meta property="og:url" content="http://www.danawa.com">\n<meta property="og:type" content="website">\n<meta property="og:description" content="가격비교 사이트 - 온라인 쇼핑몰, 소셜커머스 전 상품 정보 가격비교 사이트, 비교하면 다나와">\n<meta property="og:site_name" content
# ...
